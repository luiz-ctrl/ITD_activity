# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
penguins = pd.read_csv('datasets\\penguins.csv')

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %% [markdown]
# <h1>Data Exploration</h1>

# %%
penguins['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
penguins['species'] == 'Adelie'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %% [markdown]
# <h1>Insight no.1-3</h1>
# <h2>#1 Does the penguin specie 'Adelie' lives exclusively on an island</h2>
# <p>Adelie on Biscoe Island</p>

# %%
[penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Biscoe')].count()]
# Out:
# [rowid                44
#  species              44
#  island               44
#  bill_length_mm       44
#  bill_depth_mm        44
#  flipper_length_mm    44
#  body_mass_g          44
#  sex                  44
#  year                 44
#  dtype: int64]

# %%
AB = penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Biscoe')]
AB
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20      21  Adelie  Biscoe            37.8           18.3              174.0
# 21      22  Adelie  Biscoe            37.7           18.7              180.0
# 22      23  Adelie  Biscoe            35.9           19.2              189.0
# 23      24  Adelie  Biscoe            38.2           18.1              185.0
# 24      25  Adelie  Biscoe            38.8           17.2              180.0
# 25      26  Adelie  Biscoe            35.3           18.9              187.0
# 26      27  Adelie  Biscoe            40.6           18.6              183.0
# 27      28  Adelie  Biscoe            40.5           17.9              187.0
# 28      29  Adelie  Biscoe            37.9           18.6              172.0
# 29      30  Adelie  Biscoe            40.5           18.9              180.0
# 50      51  Adelie  Biscoe            39.6           17.7              186.0
# ...

# %%
penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Torsergen')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
AT = penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Torsergen')]
AT
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Dream')].count()
# Out:
# rowid                56
# species              56
# island               56
# bill_length_mm       56
# bill_depth_mm        56
# flipper_length_mm    56
# body_mass_g          56
# sex                  55
# year                 56
# dtype: int64

# %%
AD = penguins[(penguins['species'] == 'Adelie') & (penguins['island'] == 'Dream')]
AD
# Out:
#      rowid species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      31  Adelie  Dream            39.5           16.7              178.0
# 31      32  Adelie  Dream            37.2           18.1              178.0
# 32      33  Adelie  Dream            39.5           17.8              188.0
# 33      34  Adelie  Dream            40.9           18.9              184.0
# 34      35  Adelie  Dream            36.4           17.0              195.0
# 35      36  Adelie  Dream            39.2           21.1              196.0
# 36      37  Adelie  Dream            38.8           20.0              190.0
# 37      38  Adelie  Dream            42.2           18.5              180.0
# 38      39  Adelie  Dream            37.6           19.3              181.0
# 39      40  Adelie  Dream            39.8           19.1              184.0
# 40      41  Adelie  Dream            36.5           18.0              182.0
# ...

# %%
penguins[(penguins['species'] == 'Chinstrap') & (penguins['island'] == 'Biscoe')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
CB = penguins[(penguins['species'] == 'Gentoo') & (penguins['island'] == 'Biscoe')]
CB
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152    153  Gentoo  Biscoe            46.1           13.2              211.0
# 153    154  Gentoo  Biscoe            50.0           16.3              230.0
# 154    155  Gentoo  Biscoe            48.7           14.1              210.0
# 155    156  Gentoo  Biscoe            50.0           15.2              218.0
# 156    157  Gentoo  Biscoe            47.6           14.5              215.0
# ..     ...     ...     ...             ...            ...                ...
# 271    272  Gentoo  Biscoe             NaN            NaN                NaN
# 272    273  Gentoo  Biscoe            46.8           14.3              215.0
# 273    274  Gentoo  Biscoe            50.4           15.7              222.0
# 274    275  Gentoo  Biscoe            45.2           14.8              212.0
# 275    276  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[(penguins['species'] == 'Chinstrap') & (penguins['island'] == 'Torsergen')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
CT = penguins[(penguins['species'] == 'Chinstrap') & (penguins['island'] == 'Torsergen')]
CT
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
penguins[(penguins['species'] == 'Chinstrap') & (penguins['island'] == 'Dream')].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# dtype: int64

# %%
CD = penguins[(penguins['species'] == 'Chinstrap') & (penguins['island'] == 'Dream')]
CD
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 276    277  Chinstrap  Dream            46.5           17.9
# 277    278  Chinstrap  Dream            50.0           19.5
# 278    279  Chinstrap  Dream            51.3           19.2
# 279    280  Chinstrap  Dream            45.4           18.7
# 280    281  Chinstrap  Dream            52.7           19.8
# ..     ...        ...    ...             ...            ...
# 339    340  Chinstrap  Dream            55.8           19.8
# 340    341  Chinstrap  Dream            43.5           18.1
# 341    342  Chinstrap  Dream            49.6           18.2
# 342    343  Chinstrap  Dream            50.8           19.0
# 343    344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 276              192.0       3500.0  female  2007
# 277              196.0       3900.0    male  2007
# 278              193.0       3650.0    male  2007
# ...

# %%
penguins[(penguins['species'] == 'Gentoo') & (penguins['island'] == 'Dream')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
GD = penguins[(penguins['species'] == 'Gentoo') & (penguins['island'] == 'Dream')]
GD
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
penguins[(penguins['species'] == 'Gentoo') & (penguins['island'] == 'Torsergen')].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
GT = penguins[(penguins['species'] == 'Gentoo') & (penguins['island'] == 'Torsergen')]
GT
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
penguins[(penguins['species'] == 'Gentoo') & (penguins['island'] == 'Biscoe')].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       123
# bill_depth_mm        123
# flipper_length_mm    123
# body_mass_g          123
# sex                  119
# year                 124
# dtype: int64

# %%
GB = penguins[(penguins['species'] == 'Gentoo') & (penguins['island'] == 'Biscoe')]
GB
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152    153  Gentoo  Biscoe            46.1           13.2              211.0
# 153    154  Gentoo  Biscoe            50.0           16.3              230.0
# 154    155  Gentoo  Biscoe            48.7           14.1              210.0
# 155    156  Gentoo  Biscoe            50.0           15.2              218.0
# 156    157  Gentoo  Biscoe            47.6           14.5              215.0
# ..     ...     ...     ...             ...            ...                ...
# 271    272  Gentoo  Biscoe             NaN            NaN                NaN
# 272    273  Gentoo  Biscoe            46.8           14.3              215.0
# 273    274  Gentoo  Biscoe            50.4           15.7              222.0
# 274    275  Gentoo  Biscoe            45.2           14.8              212.0
# 275    276  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h1>Insight no.4-6</h1>

# %% [markdown]
# <h1>Does the island affects the weight or body mass of a penguin specie ?</h1>

# %%
AB['body_mass_g'].mean()
# Out:
# np.float64(3709.659090909091)

# %%
np.round(AB['body_mass_g'].mean(),1)
# Out:
# np.float64(3709.7)

# %%
AT['body_mass_g'].mean()
np.round(AT['body_mass_g'].mean(),1)
# Out:
# np.float64(nan)

# %%
AD['body_mass_g'].mean()
np.round(AD['body_mass_g'].mean(),1)
# Out:
# np.float64(3688.4)

# %%
CB['body_mass_g'].mean()
np.round(CB['body_mass_g'].mean(),1)
# Out:
# np.float64(5076.0)

# %%
CT['body_mass_g'].mean()
np.round(CT['body_mass_g'].mean(),1)
# Out:
# np.float64(nan)

# %%
CD['body_mass_g'].mean()
np.round(CD['body_mass_g'].mean(),1)
# Out:
# np.float64(3733.1)

# %%
GB['body_mass_g'].mean()
np.round(GB['body_mass_g'].mean(),1)
# Out:
# np.float64(5076.0)

# %%
GT['body_mass_g'].mean()
np.round(GT['body_mass_g'].mean(),1)
# Out:
# np.float64(nan)

# %%
GD['body_mass_g'].mean()
np.round(GD['body_mass_g'].mean(),1)
# Out:
# np.float64(nan)

# %%
penguins['wkilo'] = np.round(penguins['body_mass_g']/ 1000, 1)
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  wkilo
# 0                181.0       3750.0    male  2007    3.8
# 1                186.0       3800.0  female  2007    3.8
# ...

# %% [markdown]
# <h1>Insight no.7</h1>
# <h2>The Adelie Species has an average weight of 3.7kilo regardless of the island location where they lived ?</h2>

# %%
#Adelie

# %%
AB = (penguins['wkilo'].mean())
AB
# Out:
# np.float64(4.202046783625731)

# %%
AT = (penguins['wkilo'].mean())
AT
# Out:
# np.float64(4.202046783625731)

# %%
AD = (penguins['wkilo'].mean())
AD
# Out:
# np.float64(4.202046783625731)

# %%
#Chinstrap

# %%
CB = (penguins['wkilo'].mean())
CB
# Out:
# np.float64(4.202046783625731)

# %%
CT = (penguins['wkilo'].mean())
CT
# Out:
# np.float64(4.202046783625731)

# %%
CD = (penguins['wkilo'].mean())
CD
# Out:
# np.float64(4.202046783625731)

# %%
#Gentoo

# %%
GB = (penguins['wkilo'].mean())
GB
# Out:
# np.float64(4.202046783625731)

# %%
GT = (penguins['wkilo'].mean())
GT
# Out:
# np.float64(4.202046783625731)

# %%
GD = (penguins['wkilo'].mean())
GD
# Out:
# np.float64(4.202046783625731)

# %% [markdown]
# <h1>#</h1>

# %%
penguins_agg = penguins.groupby(["species", "island", "sex"]).count()
penguins_agg
# Out:
#                             rowid  bill_length_mm  bill_depth_mm  \
# species   island    sex
# Adelie    Biscoe    female     22              22             22
#                     male       22              22             22
#           Dream     female     27              27             27
#                     male       28              28             28
#           Torgersen female     24              24             24
#                     male       23              23             23
# Chinstrap Dream     female     34              34             34
#                     male       34              34             34
# Gentoo    Biscoe    female     58              58             58
#                     male       61              61             61
#
#                             flipper_length_mm  body_mass_g  year  wkilo
# species   island    sex
# Adelie    Biscoe    female                 22           22    22     22
# ...

# %% [markdown]
# <h1>Insight no.8</h1>
# <h2>What year has the Most Male Adelie</h2>

# %%
penguins_agg = penguins.groupby(["species", "year", "sex"]).size()
penguins_agg
# Out:
# species    year  sex
# Adelie     2007  female    22
#                  male      22
#            2008  female    25
#                  male      25
#            2009  female    26
#                  male      26
# Chinstrap  2007  female    13
#                  male      13
#            2008  female     9
#                  male       9
#            2009  female    12
#                  male      12
# Gentoo     2007  female    16
#                  male      17
#            2008  female    22
#                  male      23
#            2009  female    20
#                  male      21
# dtype: int64

# %%
penguins_agg.unstack()
# Out:
# sex             female  male
# species   year
# Adelie    2007      22    22
#           2008      25    25
#           2009      26    26
# Chinstrap 2007      13    13
#           2008       9     9
#           2009      12    12
# Gentoo    2007      16    17
#           2008      22    23
#           2009      20    21

# %% [markdown]
# <h1>Question no.9</h1>
# <h2>Which is heavier between penguins species in terms of SEX?</h2>

# %%
w_sex = np.round(penguins.groupby(['species','sex'])['wkilo'].mean(), 1)

# %%
w_sex
# Out:
# species    sex
# Adelie     female    3.4
#            male      4.0
# Chinstrap  female    3.5
#            male      3.9
# Gentoo     female    4.7
#            male      5.5
# Name: wkilo, dtype: float64

# %%
w_sex.unstack()
# Out:
# sex        female  male
# species
# Adelie        3.4   4.0
# Chinstrap     3.5   3.9
# Gentoo        4.7   5.5

# %% [markdown]
# <h1>Question no.10</h1>
# <h2>What year has the highest recorded weight for Male and Female?</h2>

# %%
year = np.round(penguins.groupby(['sex', 'year'])['wkilo'].mean(), 1)
year
# Out:
# sex     year
# female  2007    3.8
#         2008    3.9
#         2009    3.9
# male    2007    4.5
#         2008    4.6
#         2009    4.5
# Name: wkilo, dtype: float64

# %% [markdown]
# <h1>Question no.11</h1>
# <h2>Correlation between Bill Lenght and Bill Depth?</h2>

# %% [markdown]
# <h1>Statistical Treatment</h1>
# <h2>Used for measuring correlation between quantitative Data</h2>

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  wkilo
# 0                181.0       3750.0    male  2007    3.8
# 1                186.0       3800.0  female  2007    3.8
# ...

# %% [markdown]
# <h1>Insight no.11</h1>
# <h2>There is no Correlation between Bill Lenght and Bill Depht</h2>

# %%
b_length_depth = penguins['bill_length_mm'].corr(penguins['bill_depth_mm'])
b_length_depth
# Out:
# np.float64(-0.23505287035553257)

# %% [markdown]
# <h1>Insight no.12</h1>
# <h2>There is correlation between Bill Length and Body Mass</h2>

# %%
b_length = penguins['bill_length_mm'].corr(penguins['body_mass_g'])
b_length
# Out:
# np.float64(0.5951098244376303)

# %% [markdown]
# <h1>Insight no.13</h1>
# <h2>There is correlation between Flipper Length and Body Mass</h2>

# %%
f_length = penguins['flipper_length_mm'].corr(penguins['body_mass_g'])
f_length
# Out:
# np.float64(0.8712017673060113)

# %% [markdown]
# <h1>Insight no.14</h1>
# <h2>There is correlation between Flipper Length and Wkilo</h2>

# %%
flm = penguins['flipper_length_mm'].corr(penguins['wkilo'])
flm
# Out:
# np.float64(0.8706550442461823)

# %% [markdown]
# <h1>Science Python Library -- Known as Scipy</h1>

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC46\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from scipy.stats import f_oneway

# %% [markdown]
# <h1>testing correlation between body mass and sex</h1>

# %% [markdown]
# <h1>Insight no.15</h1>
# <h2>There is a correlation between body mass and sex</h2>

# %%
f_stats, p_value = f_oneway(penguins[penguins['sex'] == 'male']['body_mass_g'],
                           penguins[penguins['sex'] == 'female']['body_mass_g'])
p_value
# Out:
# np.float64(4.897246751596225e-16)

# %% [markdown]
# <h1>Insight no.16</h1>
# <h2>There is a correlation between sex and flipper lenght</h2>

# %%
f_stats, p_value = f_oneway(penguins[penguins['sex'] == 'male']['flipper_length_mm'],
                           penguins[penguins['sex'] == 'female']['flipper_length_mm'])
p_value
# Out:
# np.float64(2.3910970925541695e-06)
