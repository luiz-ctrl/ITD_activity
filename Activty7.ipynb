# %% [markdown]
# <h1>Data Analyst: Luiz Kieth Patiag</h1>
# <h2>BSIT 3B</h2>
# <h3>Activity 7</h3>

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Chicago_Crimes.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#               ID Case Number                    Date                  Block  \
# 0       13439321    JH237424  04/14/2024 12:00:00 AM    040XX S PRAIRIE AVE
# 1       13437420    JH234779  04/14/2024 12:00:00 AM      023XX W CERMAK RD
# 2       13428676    JH224478  04/14/2024 12:00:00 AM    043XX W LE MOYNE ST
# 3       13429357    JH225293  04/14/2024 12:00:00 AM       039XX W ADAMS ST
# 4       13430098    JH226395  04/14/2024 12:00:00 AM       011XX W 112TH PL
# ...          ...         ...                     ...                    ...
# 249118  13805239    JJ217509  04/12/2025 12:00:00 AM     029XX W LOGAN BLVD
# 249119  13804023    JJ215813  04/12/2025 12:00:00 AM    094XX S HARVARD AVE
# 249120  13803926    JJ215943  04/12/2025 12:00:00 AM  084XX S VINCENNES AVE
# 249121  13803475    JJ215338  04/12/2025 12:00:00 AM    050XX S ABERDEEN ST
# 249122  13804512    JJ216668  04/12/2025 12:00:00 AM    012XX W CARROLL AVE
#
# ...

# %%
import folium

# %%
from folium.plugins import HeatMap

# %%
df['Updated On'] = pd.to_datetime(df['Updated On'],dayfirst=True,errors = 'coerce')

# %%
df['Month'] = df['Updated On'].dt.month

# %%
df['Primary Type'].value_counts()
# Out:
# Primary Type
# THEFT                                59201
# BATTERY                              44579
# CRIMINAL DAMAGE                      27094
# ASSAULT                              22615
# MOTOR VEHICLE THEFT                  19604
# OTHER OFFENSE                        16781
# DECEPTIVE PRACTICE                   14991
# BURGLARY                              8443
# ROBBERY                               8200
# WEAPONS VIOLATION                     7164
# NARCOTICS                             6627
# CRIMINAL TRESPASS                     5045
# OFFENSE INVOLVING CHILDREN            1597
# CRIMINAL SEXUAL ASSAULT               1573
# SEX OFFENSE                           1210
# PUBLIC PEACE VIOLATION                1006
# INTERFERENCE WITH PUBLIC OFFICER       771
# HOMICIDE                               553
# STALKING                               520
# ARSON                                  452
# PROSTITUTION                           287
# ...

# %%
df['District'].value_counts()
# Out:
# District
# 8     16691
# 12    15355
# 1     14409
# 6     14157
# 19    13640
# 11    13423
# 4     13318
# 18    13118
# 2     12848
# 25    12664
# 3     12545
# 9     10910
# 7     10520
# 10    10133
# 5      9883
# 14     9341
# 15     8605
# 16     8570
# 24     8101
# 17     7801
# 22     7710
# 20     5362
# 31       19
# Name: count, dtype: int64

# %%
theft_crimes = df[df['Primary Type'] == 'THEFT']
battery_crimes = df[df['Primary Type'] == 'BATTERY']
criminal_damage_crimes = df[df['Primary Type'] == 'CRIMINAL DAMAGE']
assault_crimes = df[df['Primary Type'] == 'ASSAULT']
motor_vehicle_theft_crimes = df[df['Primary Type'] == 'MOTOR VEHICLE THEFT']
other_offenses = df[df['Primary Type'] == 'OTHER OFFENSE']
deceptive_practice_crimes = df[df['Primary Type'] == 'DECEPTIVE PRACTICE']
burglary_crimes = df[df['Primary Type'] == 'BURGLARY']
robbery_crimes = df[df['Primary Type'] == 'ROBBERY']
weapons_violation_crimes = df[df['Primary Type'] == 'WEAPONS VIOLATION']
narcotics_crimes = df[df['Primary Type'] == 'NARCOTICS']
criminal_trespass_crimes = df[df['Primary Type'] == 'CRIMINAL TRESPASS']
offenses_involving_children = df[df['Primary Type'] == 'OFFENSE INVOLVING CHILDREN']
criminal_sexual_assault_crimes = df[df['Primary Type'] == 'CRIMINAL SEXUAL ASSAULT']
sex_offense_crimes = df[df['Primary Type'] == 'SEX OFFENSE']
public_peace_violations = df[df['Primary Type'] == 'PUBLIC PEACE VIOLATION']
interference_with_public_officer_crimes = df[df['Primary Type'] == 'INTERFERENCE WITH PUBLIC OFFICER']
homicide_crimes = df[df['Primary Type'] == 'HOMICIDE']
stalking_crimes = df[df['Primary Type'] == 'STALKING']
arson_crimes = df[df['Primary Type'] == 'ARSON']
prostitution_crimes = df[df['Primary Type'] == 'PROSTITUTION']
concealed_carry_license_violations = df[df['Primary Type'] == 'CONCEALED CARRY LICENSE VIOLATION']
liquor_law_violations = df[df['Primary Type'] == 'LIQUOR LAW VIOLATION']
intimidation_crimes = df[df['Primary Type'] == 'INTIMIDATION']
kidnapping_crimes = df[df['Primary Type'] == 'KIDNAPPING']
obscenity_crimes = df[df['Primary Type'] == 'OBSCENITY']
human_trafficking_crimes = df[df['Primary Type'] == 'HUMAN TRAFFICKING']
gambling_crimes = df[df['Primary Type'] == 'GAMBLING']
public_indecency_crimes = df[df['Primary Type'] == 'PUBLIC INDECENCY']
other_narcotic_violations = df[df['Primary Type'] == 'OTHER NARCOTIC VIOLATION']
non_criminal_offenses = df[df['Primary Type'] == 'NON-CRIMINAL']

# %%
district_1_crimes = df[df['District'] == 1]
district_2_crimes = df[df['District'] == 2]
district_3_crimes = df[df['District'] == 3]
district_4_crimes = df[df['District'] == 4]
district_5_crimes = df[df['District'] == 5]
district_6_crimes = df[df['District'] == 6]
district_7_crimes = df[df['District'] == 7]
district_8_crimes = df[df['District'] == 8]
district_9_crimes = df[df['District'] == 9]
district_10_crimes = df[df['District'] == 10]
district_11_crimes = df[df['District'] == 11]
district_12_crimes = df[df['District'] == 12]
district_13_crimes = df[df['District'] == 13]
district_14_crimes = df[df['District'] == 14]
district_15_crimes = df[df['District'] == 15]
district_16_crimes = df[df['District'] == 16]
district_17_crimes = df[df['District'] == 17]
district_18_crimes = df[df['District'] == 18]
district_19_crimes = df[df['District'] == 19]
district_20_crimes = df[df['District'] == 20]
district_21_crimes = df[df['District'] == 21]
district_22_crimes = df[df['District'] == 22]
district_23_crimes = df[df['District'] == 23]
district_24_crimes = df[df['District'] == 24]
district_25_crimes = df[df['District'] == 25]
district_26_crimes = df[df['District'] == 26]
district_27_crimes = df[df['District'] == 27]
district_28_crimes = df[df['District'] == 28]
district_29_crimes = df[df['District'] == 29]
district_30_crimes = df[df['District'] == 30]
district_31_crimes = df[df['District'] == 31]

# %%
primary_types = [
    'THEFT', 'BATTERY', 'CRIMINAL DAMAGE', 'ASSAULT', 
    'MOTOR VEHICLE THEFT', 'OTHER OFFENSE', 'DECEPTIVE PRACTICE', 
    'BURGLARY', 'ROBBERY', 'WEAPONS VIOLATION', 'NARCOTICS', 
    'CRIMINAL TRESPASS', 'OFFENSE INVOLVING CHILDREN', 
    'CRIMINAL SEXUAL ASSAULT', 'SEX OFFENSE', 
    'PUBLIC PEACE VIOLATION', 'INTERFERENCE WITH PUBLIC OFFICER', 
    'HOMICIDE', 'STALKING', 'ARSON', 'PROSTITUTION', 
    'CONCEALED CARRY LICENSE VIOLATION', 'LIQUOR LAW VIOLATION', 
    'INTIMIDATION', 'KIDNAPPING', 'OBSCENITY', 
    'HUMAN TRAFFICKING', 'GAMBLING', 'PUBLIC INDECENCY', 
    'OTHER NARCOTIC VIOLATION', 'NON-CRIMINAL'
]
district_11_filters = {}

for crime_type in primary_types:
    district_11_filters[f'filter_D11_{crime_type.lower().replace(" ", "_")}'] = df[df['District'] == 11][df['Primary Type'] == crime_type]

# %%
filter_D11_theft = district_11_filters['filter_D11_theft']

# %%
filter_D11_theft
# Out:
#               ID Case Number                    Date  \
# 174     13428574    JH224355  04/14/2024 03:14:00 AM
# 550     13429177    JH225139  04/14/2024 06:05:00 PM
# 1257    13455255    JH257173  04/15/2024 04:59:00 PM
# 1281    13432476    JH229298  04/15/2024 05:15:00 PM
# 1857    13431785    JH227346  04/16/2024 03:00:00 PM
# ...          ...         ...                     ...
# 248342  13808040    JJ220402  04/10/2025 05:25:00 PM
# 248694  13803591    JJ215501  04/11/2025 10:30:00 AM
# 248872  13803322    JJ215199  04/11/2025 04:00:00 PM
# 248890  13808975    JJ221137  04/11/2025 04:42:00 PM
# 249109  13803864    JJ215663  04/12/2025 12:00:00 AM
#
#                            Block  IUCR Primary Type               Description  \
# 174            039XX W MONROE ST  0820        THEFT            $500 AND UNDER
# 550           006XX N CICERO AVE  0820        THEFT            $500 AND UNDER
# 1257    010XX N Central Park Ave  0890        THEFT             FROM BUILDING
# ...

# %%
for crime_type in primary_types:
    
    filtered_data = df[(df['Primary Type'] == crime_type) & (df['District'] == 11)]
    coordinates = filtered_data.groupby(['Latitude', 'Longitude']).size().reset_index(name='incident_count')

    if not coordinates.empty:
        heatmap_data = coordinates[['Latitude', 'Longitude', 'incident_count']].values.tolist()
        heatmap_map = folium.Map(location=[41.7750, -87.7000], zoom_start=12)
        HeatMap(heatmap_data, radius=12).add_to(heatmap_map)
        heatmap_map.save(f'heatmap_{crime_type.lower().replace(" ", "_")}_district_11.html')

print("Heatmaps created for all specified crime types in District 11.")
# Out:
# Heatmaps created for all specified crime types in District 11.
